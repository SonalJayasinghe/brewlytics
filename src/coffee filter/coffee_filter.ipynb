# %% [markdown]
# # Data Import

# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('combined_data.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %%
df.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin                                 Farm.Name Lot.Number       Mill ICO.Number                                Company       Altitude        Region                               Producer  Number.of.Bags Bag.Weight                  In.Country.Partner Harvest.Year      Grading.Date                   Owner.1  Variety Processing.Method  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  Clean.Cup  Sweetness  Cupper.Points  Total.Cup.Points  Moisture  Category.One.Defects  Quakers  Color  Category.Two.Defects        Expiration                  Certification.Body                     Certification.Address                     Certification.Contact unit_of_measurement  altitude_low_meters  altitude_high_meters  altitude_mean_meters
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Identify Unnecessary Columns

# %%
df.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin                                 Farm.Name Lot.Number       Mill ICO.Number                                Company       Altitude        Region                               Producer  Number.of.Bags Bag.Weight                  In.Country.Partner Harvest.Year      Grading.Date                   Owner.1  Variety Processing.Method  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  Clean.Cup  Sweetness  Cupper.Points  Total.Cup.Points  Moisture  Category.One.Defects  Quakers  Color  Category.Two.Defects        Expiration                  Certification.Body                     Certification.Address                     Certification.Contact unit_of_measurement  altitude_low_meters  altitude_high_meters  altitude_mean_meters
# ...

# %%
def calculate_pre_statistics(data):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'non_null_count': df.notnull().sum(),
        'missing_pct': (df.isnull().mean() * 100).round(2),
        'unique_values': df.nunique(dropna=True)
    })
    summary['feature_type'] = summary['dtype'].apply(lambda x: 'numeric' if np.issubdtype(x, np.number) else 'categorical')
    summary.reset_index(inplace=True)
    summary.rename(columns={'index': 'column'}, inplace=True)

    display(summary)

calculate_pre_statistics(df)
# Out:
#                    column    dtype  non_null_count  missing_pct  unique_values feature_type
# 0              Unnamed: 0  float64            1311        22.75           1311      numeric
# 1                 Species   object            1311        22.75              1  categorical
# 2                   Owner   object            1688         0.53            471  categorical
# 3       Country.of.Origin   object            1694         0.18             39  categorical
# 4               Farm.Name   object            1338        21.15            854  categorical
# 5              Lot.Number   object             654        61.46            430  categorical
# 6                    Mill   object            1382        18.56            656  categorical
# 7              ICO.Number   object            1221        28.05            894  categorical
# 8                 Company   object            1482        12.67            436  categorical
# ...

# %% [markdown]
# I can see that Certification.Body, Certification.Address, Certification.Contact, ICO.Number, Lot.Number, Species, Unnamed: 0  columns can be deleted safely.

# %%
df.drop(columns=['Certification.Body', 'Certification.Address','Certification.Contact', 'ICO.Number', 'Lot.Number', 'Species', 'Unnamed: 0' ], inplace=True)

# %%
calculate_pre_statistics(df)
# Out:
#                   column    dtype  non_null_count  missing_pct  unique_values feature_type
# 0                  Owner   object            1688         0.53            471  categorical
# 1      Country.of.Origin   object            1694         0.18             39  categorical
# 2              Farm.Name   object            1338        21.15            854  categorical
# 3                   Mill   object            1382        18.56            656  categorical
# 4                Company   object            1482        12.67            436  categorical
# 5               Altitude   object            1470        13.38            468  categorical
# 6                 Region   object            1637         3.54            554  categorical
# 7               Producer   object            1465        13.67            959  categorical
# 8         Number.of.Bags  float64            1695         0.12            160      numeric
# ...
